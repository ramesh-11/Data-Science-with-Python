# %% [markdown]
# # Seaborn exercises
#
# In this section, using Seaborn library, we will explore a dataset from:
#
# https://archive.ics.uci.edu/ml/datasets/Student+Performance
#
# Dataset is already included in the folder, there is no need to download.

# %% [markdown]
# #### Import pandas as pd, numpy as np, matplotlib.pyplot as plt and seaborn as sns:

# %% [markdown]
# #### Read the "data_student.csv" file using read_csv() (Hint: indicate ';' as the seperator and indicate not to read in index column) and check its head:

# %%
# Out:
#   school sex  age famsize Pstatus  Medu     Mjob  reason  traveltime  \
# 0     GP   F   18     GT3       A     4  at_home  course           2
# 1     GP   F   17     GT3       T     1  at_home  course           1
# 2     GP   F   15     LE3       T     1  at_home   other           1
# 3     GP   F   15     GT3       T     4   health    home           1
# 4     GP   F   16     GT3       T     3    other    home           1
#
#    studytime  freetime  health  absences  G2  G3
# 0          2         3       3         6   6   6
# 1          2         3       3         4   5   6
# 2          2         3       3        10   8  10
# 3          3         2       5         2  14  15
# 4          2         3       5         4  10  10

# %% [markdown]
# #### Get general information about DataFrame:

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395 entries, 0 to 394
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   famsize     395 non-null    object
#  4   Pstatus     395 non-null    object
#  5   Medu        395 non-null    int64
#  6   Mjob        395 non-null    object
#  7   reason      395 non-null    object
#  8   traveltime  395 non-null    int64
#  9   studytime   395 non-null    int64
#  10  freetime    395 non-null    int64
#  11  health      395 non-null    int64
#  12  absences    395 non-null    int64
#  13  G2          395 non-null    int64
#  14  G3          395 non-null    int64
# dtypes: int64(9), object(6)
# memory usage: 49.4+ KB

# %% [markdown]
# #### Plot the number of students for each school and categorize it by sex:
# #### Hint: countplot

# %% [markdown]
# #### Plot age distribution of the students (include kde):

# %% [markdown]
# #### Plot average of students for each school:

# %% [markdown]
# #### Plot the quartiles of final grade (G3) of the students catogorized by mother's education (Medu):
# #### Hint: boxplot
# Info:
#
#  0 - None
#
#  1 - primary education (4th grade),
#
#  2 – 5th to 9th grade,
#
#  3 – secondary education
#
#  4 – higher education

# %% [markdown]
# #### Plot probability density with regards to final grade (G3) and mother's job (Mjob) and consider sex by selecting split = True:
# #### Hint: violinplot

# %% [markdown]
# #### Plot density distribution of the grades (both G2,G3 on the same canvas)  with regards to health but this time we want to see every data as a point in our plot:
# #### Hint: swarm plot, subplot
#
# Info:
# health status (numeric: from 1 - very bad to 5 - very good)

# %%
fig, axes = plt.subplots(1,2,figsize=(13,5))

#create plots here

# %% [markdown]
# #### Do the same for the absences and travel time (single plot is enough):

# %% [markdown]
# #### Plot the final grade (G3) with respect to parental status(Pstatus) and family size (famsize) using FacetGrid and distplot (set kde=False):
#
# Info:
#
# LE3 - less than and equal to 3
#
# GT3 - greater than 3
#
# A - Apart
#
# T - Together

# %% [markdown]
# #### Plot a categorical relationship between study time (studytime) and mean of final grade (G3) and categorize by parental status:
#
# #### Hint: barplot

# %% [markdown]
# #### Plot the relationship between max. midterm grade (G2) and reason for choosing the school (reason) and categorize it by sex:
#
# #### Hint: We need bar plot but let us use catplot to reach the same plot

# %% [markdown]
# #### Plot the distribution of the final grade (G3) of the students using kde. Plot for both gender type on the same plot:
#
# #### Hint: distplot using logical masking could come in handy.
# ###### students[students['sex']=='M']['G3']
# ###### students[students['sex']=='F']['G3']

# %% [markdown]
# #### This time plot the distribution of midterm grade (G2) using kde together for each freetime amount:
#
# #### Hint: Previously we had 2 plots together. This time we have 5, so let's use for loop instead.

# %% [markdown]
# #### Create a jointplot for relationship between midterm (G2) and final grades (G3) with kde:

# %% [markdown]
# #### Let's do the same for absences and midterm grade (G2) but this time with hex:

# %% [markdown]
# #### Plot the relationship between midterm (G2), final (G3) grade and absences:
#
# #### Hint: we have more than 2 columns to pair.

# %% [markdown]
# ## Well done!
