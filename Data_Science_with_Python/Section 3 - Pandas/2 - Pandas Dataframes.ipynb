# %% [markdown]
# ## DataFrames
#
# DataFrames are actually multiple Series sharing the same index. DataFrames are very important when it comes to large datasets.
#
# Let's jump on to the examples to see why!

# %%
import numpy as np
import pandas as pd

from pandas import Series,DataFrame

# %%
list1 = [[0,1,2,3],[4,5,6,7]]  ##  or list1 = [[0,1,2,3],  
                               ##              [4,5,6,7]]

# %%
df = DataFrame(data=list1,index=['row1','row2'],
              columns=['col1','col2','col3','col4'])
df
# Out:
#       col1  col2  col3  col4
# row1     0     1     2     3
# row2     4     5     6     7

# %%
array = np.arange(8)
array
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
array.reshape(2,4)
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
df = DataFrame(np.arange(8).reshape(2,4),index=['row1','row2'],
              columns=['col1','col2','col3','col4'])
df
# Out:
#       col1  col2  col3  col4
# row1     0     1     2     3
# row2     4     5     6     7

# %% [markdown]
# ### read_csv
#
# Let's import a csv file as DataFrame using read_csv and continue using this data:

# %%
nba = pd.read_csv('data_nba.csv')
nba
# Out:
#    Rank                    Team    Won   Lost   Pct. First NBA season  \
# 0     1       San Antonio Spurs  2,162  1,316  0.622          1976–77
# 1     2      Los Angeles Lakers  3,333  2,282  0.594          1948–49
# 2     3          Boston Celtics  3,378  2,346  0.590          1946–47
# 3     4   Oklahoma City Thunder  2,283  1,933  0.542          1967–68
# 4     5               Utah Jazz  1,964  1,678  0.539          1974–75
# 5     6  Portland Trail Blazers  2,134  1,836  0.538          1970–71
# 6     7            Phoenix Suns  2,186  1,948  0.529          1968–69
# 7     8         Houston Rockets  2,225  1,991  0.528          1967–68
# 8     9              Miami Heat  1,294  1,200  0.519          1988–89
# 9    10         Milwaukee Bucks  2,129  2,005  0.515          1968–69
#
#   Total games   Division
# 0       3,478  Southwest
# 1       5,615    Pacific
# 2       5,724   Atlantic
# 3       4,216  Northwest
# 4       3,642  Northwest
# 5       3,970  Northwest
# 6       4,134    Pacific
# 7       4,216  Southwest
# 8       2,494  Southeast
# 9       4,134    Central

# %% [markdown]
# We can check with type() function to see if the csv file was imported as a DataFrame object:

# %%
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# some useful built-in functions for DataFrame:

# %%
nba.head()        # shows the first 5 rows by default
# Out:
#    Rank                   Team    Won   Lost   Pct. First NBA season  \
# 0     1      San Antonio Spurs  2,162  1,316  0.622          1976–77
# 1     2     Los Angeles Lakers  3,333  2,282  0.594          1948–49
# 2     3         Boston Celtics  3,378  2,346  0.590          1946–47
# 3     4  Oklahoma City Thunder  2,283  1,933  0.542          1967–68
# 4     5              Utah Jazz  1,964  1,678  0.539          1974–75
#
#   Total games   Division
# 0       3,478  Southwest
# 1       5,615    Pacific
# 2       5,724   Atlantic
# 3       4,216  Northwest
# 4       3,642  Northwest

# %%
nba.head(2)      #number of rows to show can be passed into the function
# Out:
#    Rank                Team    Won   Lost   Pct. First NBA season Total games  \
# 0     1   San Antonio Spurs  2,162  1,316  0.622          1976–77       3,478
# 1     2  Los Angeles Lakers  3,333  2,282  0.594          1948–49       5,615
#
#     Division
# 0  Southwest
# 1    Pacific

# %%
nba.tail()         #show the last 5 rows by default
# Out:
#    Rank                    Team    Won   Lost   Pct. First NBA season  \
# 5     6  Portland Trail Blazers  2,134  1,836  0.538          1970–71
# 6     7            Phoenix Suns  2,186  1,948  0.529          1968–69
# 7     8         Houston Rockets  2,225  1,991  0.528          1967–68
# 8     9              Miami Heat  1,294  1,200  0.519          1988–89
# 9    10         Milwaukee Bucks  2,129  2,005  0.515          1968–69
#
#   Total games   Division
# 5       3,970  Northwest
# 6       4,134    Pacific
# 7       4,216  Southwest
# 8       2,494  Southeast
# 9       4,134    Central

# %%
nba.tail(2)     #number of rows to show can be passed into the function
# Out:
#    Rank             Team    Won   Lost   Pct. First NBA season Total games  \
# 8     9       Miami Heat  1,294  1,200  0.519          1988–89       2,494
# 9    10  Milwaukee Bucks  2,129  2,005  0.515          1968–69       4,134
#
#     Division
# 8  Southeast
# 9    Central

# %%
nba.columns        # column labels
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Pct.', 'First NBA season',
#        'Total games', 'Division'],
#       dtype='object')

# %%
nba.index            # index info
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
nba['Team']          # selecting a column
# Out:
# 0         San Antonio Spurs
# 1        Los Angeles Lakers
# 2            Boston Celtics
# 3     Oklahoma City Thunder
# 4                 Utah Jazz
# 5    Portland Trail Blazers
# 6              Phoenix Suns
# 7           Houston Rockets
# 8                Miami Heat
# 9           Milwaukee Bucks
# Name: Team, dtype: object

# %%
nba[['Team','Lost','Won']]    # selecting multiple columns
# Out:
#                      Team   Lost    Won
# 0       San Antonio Spurs  1,316  2,162
# 1      Los Angeles Lakers  2,282  3,333
# 2          Boston Celtics  2,346  3,378
# 3   Oklahoma City Thunder  1,933  2,283
# 4               Utah Jazz  1,678  1,964
# 5  Portland Trail Blazers  1,836  2,134
# 6            Phoenix Suns  1,948  2,186
# 7         Houston Rockets  1,991  2,225
# 8              Miami Heat  1,200  1,294
# 9         Milwaukee Bucks  2,005  2,129

# %%
type(nba['Team'])    # Every column of the DataFrame is actually of Series type
                     # which means Series methods can be called for columns of a DataFrame!
# Out:
# pandas.core.series.Series

# %%
nba
# Out:
#    Rank                    Team    Won   Lost   Pct. First NBA season  \
# 0     1       San Antonio Spurs  2,162  1,316  0.622          1976–77
# 1     2      Los Angeles Lakers  3,333  2,282  0.594          1948–49
# 2     3          Boston Celtics  3,378  2,346  0.590          1946–47
# 3     4   Oklahoma City Thunder  2,283  1,933  0.542          1967–68
# 4     5               Utah Jazz  1,964  1,678  0.539          1974–75
# 5     6  Portland Trail Blazers  2,134  1,836  0.538          1970–71
# 6     7            Phoenix Suns  2,186  1,948  0.529          1968–69
# 7     8         Houston Rockets  2,225  1,991  0.528          1967–68
# 8     9              Miami Heat  1,294  1,200  0.519          1988–89
# 9    10         Milwaukee Bucks  2,129  2,005  0.515          1968–69
#
#   Total games   Division
# 0       3,478  Southwest
# 1       5,615    Pacific
# 2       5,724   Atlantic
# 3       4,216  Northwest
# 4       3,642  Northwest
# 5       3,970  Northwest
# 6       4,134    Pacific
# 7       4,216  Southwest
# 8       2,494  Southeast
# 9       4,134    Central

# %%
nba.loc[5]           # selecting a row by its index
                     # we will look more into this
# Out:
# Rank                                     6
# Team                Portland Trail Blazers
# Won                                  2,134
# Lost                                 1,836
# Pct.                                 0.538
# First NBA season                   1970–71
# Total games                          3,970
# Division                         Northwest
# Name: 5, dtype: object

# %% [markdown]
# ### Renaming the columns

# %%
new_column = ['Rank_','Team_','Won_','Lost_','Pct_',
             'First Season','Number of games','Region']

# %%
new_column_dict = dict(zip(nba.columns,new_column))   # zip object has to be converted to dictionary type
new_column_dict
# Out:
# {'Rank': 'Rank_',
#  'Team': 'Team_',
#  'Won': 'Won_',
#  'Lost': 'Lost_',
#  'Pct.': 'Pct_',
#  'First NBA season': 'First Season',
#  'Total games': 'Number of games',
#  'Division': 'Region'}

# %%
nba.rename(columns=new_column_dict,inplace=True)
nba
# Out:
#    Rank_                   Team_   Won_  Lost_   Pct_ First Season  \
# 0      1       San Antonio Spurs  2,162  1,316  0.622      1976–77
# 1      2      Los Angeles Lakers  3,333  2,282  0.594      1948–49
# 2      3          Boston Celtics  3,378  2,346  0.590      1946–47
# 3      4   Oklahoma City Thunder  2,283  1,933  0.542      1967–68
# 4      5               Utah Jazz  1,964  1,678  0.539      1974–75
# 5      6  Portland Trail Blazers  2,134  1,836  0.538      1970–71
# 6      7            Phoenix Suns  2,186  1,948  0.529      1968–69
# 7      8         Houston Rockets  2,225  1,991  0.528      1967–68
# 8      9              Miami Heat  1,294  1,200  0.519      1988–89
# 9     10         Milwaukee Bucks  2,129  2,005  0.515      1968–69
#
#   Number of games     Region
# 0           3,478  Southwest
# 1           5,615    Pacific
# 2           5,724   Atlantic
# 3           4,216  Northwest
# 4           3,642  Northwest
# 5           3,970  Northwest
# 6           4,134    Pacific
# 7           4,216  Southwest
# 8           2,494  Southeast
# 9           4,134    Central

# %% [markdown]
# ### Adding a new column

# %%
nba['Coach'] = np.arange(10)
nba
# Out:
#    Rank_                   Team_   Won_  Lost_   Pct_ First Season  \
# 0      1       San Antonio Spurs  2,162  1,316  0.622      1976–77
# 1      2      Los Angeles Lakers  3,333  2,282  0.594      1948–49
# 2      3          Boston Celtics  3,378  2,346  0.590      1946–47
# 3      4   Oklahoma City Thunder  2,283  1,933  0.542      1967–68
# 4      5               Utah Jazz  1,964  1,678  0.539      1974–75
# 5      6  Portland Trail Blazers  2,134  1,836  0.538      1970–71
# 6      7            Phoenix Suns  2,186  1,948  0.529      1968–69
# 7      8         Houston Rockets  2,225  1,991  0.528      1967–68
# 8      9              Miami Heat  1,294  1,200  0.519      1988–89
# 9     10         Milwaukee Bucks  2,129  2,005  0.515      1968–69
#
#   Number of games     Region  Coach
# 0           3,478  Southwest      0
# 1           5,615    Pacific      1
# 2           5,724   Atlantic      2
# 3           4,216  Northwest      3
# 4           3,642  Northwest      4
# 5           3,970  Northwest      5
# 6           4,134    Pacific      6
# 7           4,216  Southwest      7
# 8           2,494  Southeast      8
# 9           4,134    Central      9

# %%
two_coaches = Series(['Tarik','Berk'],index=[4,8])
two_coaches
# Out:
# 4    Tarik
# 8     Berk
# dtype: object

# %%
nba['Coach']=two_coaches
nba
# Out:
#    Rank_                   Team_   Won_  Lost_   Pct_ First Season  \
# 0      1       San Antonio Spurs  2,162  1,316  0.622      1976–77
# 1      2      Los Angeles Lakers  3,333  2,282  0.594      1948–49
# 2      3          Boston Celtics  3,378  2,346  0.590      1946–47
# 3      4   Oklahoma City Thunder  2,283  1,933  0.542      1967–68
# 4      5               Utah Jazz  1,964  1,678  0.539      1974–75
# 5      6  Portland Trail Blazers  2,134  1,836  0.538      1970–71
# 6      7            Phoenix Suns  2,186  1,948  0.529      1968–69
# 7      8         Houston Rockets  2,225  1,991  0.528      1967–68
# 8      9              Miami Heat  1,294  1,200  0.519      1988–89
# 9     10         Milwaukee Bucks  2,129  2,005  0.515      1968–69
#
#   Number of games     Region  Coach
# 0           3,478  Southwest    NaN
# 1           5,615    Pacific    NaN
# 2           5,724   Atlantic    NaN
# 3           4,216  Northwest    NaN
# 4           3,642  Northwest  Tarik
# 5           3,970  Northwest    NaN
# 6           4,134    Pacific    NaN
# 7           4,216  Southwest    NaN
# 8           2,494  Southeast   Berk
# 9           4,134    Central    NaN

# %% [markdown]
# ### Delete a column

# %%
del nba['Coach']
nba
# Out:
#    Rank_                   Team_   Won_  Lost_   Pct_ First Season  \
# 0      1       San Antonio Spurs  2,162  1,316  0.622      1976–77
# 1      2      Los Angeles Lakers  3,333  2,282  0.594      1948–49
# 2      3          Boston Celtics  3,378  2,346  0.590      1946–47
# 3      4   Oklahoma City Thunder  2,283  1,933  0.542      1967–68
# 4      5               Utah Jazz  1,964  1,678  0.539      1974–75
# 5      6  Portland Trail Blazers  2,134  1,836  0.538      1970–71
# 6      7            Phoenix Suns  2,186  1,948  0.529      1968–69
# 7      8         Houston Rockets  2,225  1,991  0.528      1967–68
# 8      9              Miami Heat  1,294  1,200  0.519      1988–89
# 9     10         Milwaukee Bucks  2,129  2,005  0.515      1968–69
#
#   Number of games     Region
# 0           3,478  Southwest
# 1           5,615    Pacific
# 2           5,724   Atlantic
# 3           4,216  Northwest
# 4           3,642  Northwest
# 5           3,970  Northwest
# 6           4,134    Pacific
# 7           4,216  Southwest
# 8           2,494  Southeast
# 9           4,134    Central

# %%
nba.drop('Team_',axis=1)
# Out:
#    Rank_   Won_  Lost_   Pct_ First Season Number of games     Region
# 0      1  2,162  1,316  0.622      1976–77           3,478  Southwest
# 1      2  3,333  2,282  0.594      1948–49           5,615    Pacific
# 2      3  3,378  2,346  0.590      1946–47           5,724   Atlantic
# 3      4  2,283  1,933  0.542      1967–68           4,216  Northwest
# 4      5  1,964  1,678  0.539      1974–75           3,642  Northwest
# 5      6  2,134  1,836  0.538      1970–71           3,970  Northwest
# 6      7  2,186  1,948  0.529      1968–69           4,134    Pacific
# 7      8  2,225  1,991  0.528      1967–68           4,216  Southwest
# 8      9  1,294  1,200  0.519      1988–89           2,494  Southeast
# 9     10  2,129  2,005  0.515      1968–69           4,134    Central
